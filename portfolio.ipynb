# %%
import portfolio as Pf
import matplotlib.pyplot as plt

# %%
code = [1808, 1898, 2428, 4188, 4502, 6178, 6384, 6986, 7201, 7224,
        7751, 7762, 7971, 8053, 8058, 8316, 8628, 8893, 9437]
units = [500, 800, 400, 300, 900, 300, 200, 200, 1000, 300,
         500, 300, 1000, 300, 300, 100, 300, 800, 700]

# %%
pf = Pf.Portfolio(code, units)

# %%
pf.add(9437, 600)

# %%
pf[9437] = 1200

# %%
pf[9437]
# Out:
# 1200

# %%
pf.remove(7224)

# %%
pf.plot()

# %%
pf.subplots()

# %%
pf.total()
